# %% [markdown]
# # 환경변수 로딩

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %% [markdown]
# # CrewAI 기본 실습

# %%
from crewai import Agent, Task, Crew
from langchain_openai import ChatOpenAI
import os

# %% [markdown]
# # 에이전트 객체 생성

# %% [markdown]
# ## 목차 작성 Agnet 정의

# %%
# 목차 설정 에이전트
outline_generator = Agent(
    role="outline_generator",
    # 주어진 주제에 대한 구조화된 목차를 생성하는 에이전트입니다. 한국어로 답변합니다.
    goal="Create structured outlines for articles on given topics. answer in Korean.",
    # 가벼운 작업을 수행하는 에이전트입니다.
    llm=ChatOpenAI(
        model="gpt-4o-mini",
        temperature=0.0,
        max_tokens=1000,
    ),
    # 목차설정치 맥락 설정, 너는 다양한 주제에 대해 포괄적인 목차를 작성하는 전문가입니다.  
    backstory="""
        You are an expert at organizing information and creating comprehensive outlines for various subjects.
        """
)

# %% [markdown]
# ## 본문 작성 Agent 정의

# %%
# 본문 작성 에이전트
writer = Agent(
    role="writer",
    goal="Create engagin content based on reshearch. answer in Korean.",
    llm=ChatOpenAI(
        model="gpt-4o-mini",
        max_tokens=3000,
    ),
    backstory="""
        You are a skilled writer who can transform complex information into readable content.
        """
)

# %% [markdown]
# # Task 정의

# %% [markdown]
# ## 목차 task

# %%
# 목차 만드는 task
outline_task = Task(
    name="outline_task",
    description="Create a detailed outline for the article about AI\'s impact on job markets.",
    agent=outline_generator,
    # 주제는 한국어로 작성합니다.
    expected_output="""
    A comprehensive outline convering the main aspects of AI\'s influence on employment
    """
)

# %% [markdown]
# ## 본문 task

# %%
# 본문 작성 task
writing_task = Task(
    name="article_task",
    description="Write a detailed article about the findings from the research",
    agent=writer,
    # 본문은 한국어로 작성합니다.
    expected_output="""
    An engaging article disussing AI's influence on job markets.
    """
)

# %% [markdown]
# # Crew 정의
# - agnet와 task를 묶는 역할

# %%
# crew 정의
ai_impact_crew = Crew(
    agents=[outline_generator, writer],
    tasks=[outline_task, writing_task], 
    # verbose=True,
)

# %% [markdown]
# # Crew 실행

# %%
import rich
from rich.console import Console

# Jupyter에서 안전한 콘솔 생성(out console 오류
console = Console(force_jupyter=True)

# import sys  
# sys.setrecursionlimit(4000)  <- 응급 처치로만 사용

# %%
# crew 실행
result = ai_impact_crew.kickoff()
result
# Out:
# CrewOutput(raw='# AI가 고용 시장에 미치는 영향: 긍정적 측면과 부정적 측면\n\n## I. 서론  \nAI(인공지능)는 기계가 인간의 지능을 모방하여 문제를 해결하고 학습할 수 있는 능력을 부여하는 기술입니다. 지난 몇십 년 간의 급속한 발전은 다양한 분야에서 AI의 영향을 확산시키고 있으며, 이로 인해 고용 시장 또한 큰 변화를 겪고 있습니다. 본 기사는 AI의 발전이 고용 시장에 미치는 영향을 심층적으로 분석하며, 긍정적인 영향과 부정적인 영향을 균형 있게 조명하려고 합니다.\n\n## II. AI의 발전과 고용 시장의 변화  \n현재 AI 기술의 발전은 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 분야에서 진행되고 있습니다. 이러한 기술들은 업무 효율성을 높이고 새로운 비즈니스 모델을 창출하는 데 기여하고 있습니다. 결과적으로 전통적인 직업에 대한 수요는 감소하는 반면, AI와 관련된 새로운 직업이 등장하고 있습니다.\n\n## III. AI의 긍정적인 영향  \n### A. 생산성 향상  \nAI는 업무 효율성을 크게 향상시킵니다. 반복적인 업무가 자동화됨으로써 직원들은 더 창의적이고 전략적인 업무에 집중할 수 있습니다. 이는 비용 절감과 더불어 기업의 전반적인 생산성을 높이는 데 기여합니다.\n\n### B. 새로운 직업 창출  \nAI의 출현은 많은 새로운 직업을 만들어냈습니다. AI 기술을 개발하고 관리하는 직무는 물론, 기술 지원 능능력이 중요한 역할을 하게 되었습니다.\n\n### C. 직무의 질 향상  \nAI 덕분에 반복적인 업무가 줄어들고, 이로 인해 직원들이 보다 전문 분야에서 발전할 수 있는 기회를 얻게 됩니다. 창의성과 전략 수립에 더 많은 시간과 자원을 투자할 수 있는 환경이 조성되고 있습니다.\n\n## IV. AI의 부정적인 영향  \n### A. 일자리 감소  \n동시에 AI는 일부 일자리를 대체하고 있습니다. 특히, 자동화에 의해 특정 산업의 전통적인 작업이 사라지면서 일자리 감소가 발생하고 있습니다. \n\n### B. 기술 격차 확대  \nAI 기술은 고급 기술을 요구하는 직업의 수를 증가시키고, 특히 저숙련 노동자는 직업을 잃거나 대체될 위험에 처하게 됩니다. 이로 인해 기술 격차가 더욱 심화되고 있습니다.\n\n### C. 사회적 불평등 심화  \n고소득 직업과 저소득 직업 간의 격차가扩大되고 있으며, 이는 지역 간 고용 불균형으로 이어지고 있습니다. 일부 지역은 AI 기술의 혜택을 누리는 반면, 다른 지역은 고용 기회가 줄어드는 상황이 발생하고 있습니다.\n\n## V. AI와 고용 시장의 미래  \n앞으로는 AI와 인간의 협업 가능성이 제기되고 있습니다. 인간과 AI의 역할 분담을 통해 인류의 다양한 업무를 더욱 효과적으로 수행할 수 있는 방법이 모색되고 있습니다. 또한, 기술 변화에 적응하기 위한 교육과 재훈련의 중요성이 강조되고 있으며, 평생 학습의 필요성이 대두되고 있습니다. 정부와 기업은 이러한 변화에 대응하기 위해 정책적 접근 방식과 책임을 가져야 합니다.\n\n## VI. 결론  \nAI는 고용 시장에 긍정적이고 부정적인 영향을 모두 미치고 있습니다. 미래의 고용 시장은 빠르게 변화하고 있으며, 이에 대한 대응책을 마련하는 것이 중요합니다. 따라서 독자 여러분께서는 이러한 변화에 발맞추어 기회를 잡고, 기술 변화에 대해 열린 마음으로 학습하는 것이 필요합니다. AI 시대에 적응하기 위해서는 계속해서 학습하고 성장하는 태도가 중요합니다.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description="Create a detailed outline for the article about AI's impact on job markets.", name='outline_task', expected_output="\n    A comprehensive outline convering the main aspects of AI's influence on employment\n    ", summary="Create a detailed outline for the article about AI's impact...", raw='**AI의 고용 시장에 미치는 영향에 대한 기사 아웃라인**\n\nI. 서론  \n   A. AI의 정의 및 발전 배경  \n   B. AI가 고용 시장에 미치는 중요성  \n   C. 기사 목적 및 구조 소개  \n\nII. AI의 발전과 고용 시장의 변화  \n   A. AI 기술의 발전 현황  \n      1. 머신러닝과 딥러닝  \n      2. 자연어 처리(NLP)  \n      3. 로봇 공학  \n   B. 고용 시장의 변화 양상  \n      1. 전통적인 직업의 변화  \n      2. 새로운 직업의 출현  \n\nIII. AI의 긍정적인 영향  \n   A. 생산성 향상  \n      1. 업무 효율성 증가  \n      2. 비용 절감  \n   B. 새로운 직업 창출  \n      1. AI 관련 직업의 증가  \n      2. 기술 지원 및 관리 직무의 필요성  \n   C. 직무의 질 향상  \n      1. 반복적인 업무의 자동화  \n      2. 창의적이고 전략적인 업무에 집중 가능  \n\nIV. AI의 부정적인 영향  \n   A. 일자리 감소  \n      1. 자동화로 인한 일자리 대체  \n      2. 특정 산업의 고용 감소  \n   B. 기술 격차 확대  \n      1. 고급 기술을 요구하는 직업의 증가  \n      2. 저숙련 노동자의 어려움  \n   C. 사회적 불평등 심화  \n      1. 고소득 직업과 저소득 직업 간의 격차  \n      2. 지역 간 고용 불균형  \n\nV. AI와 고용 시장의 미래  \n   A. AI와 인간의 협업 가능성  \n      1. 인간과 AI의 역할 분담  \n      2. 하이브리드 직무의 출현  \n   B. 교육과 재훈련의 중요성  \n      1. 기술 변화에 대한 적응 필요성  \n      2. 평생 학습의 필요성  \n   C. 정책적 대응 방안  \n      1. 정부의 역할  \n      2. 기업의 책임  \n\nVI. 결론  \n   A. AI의 고용 시장에 대한 종합적 평가  \n   B. 미래의 고용 시장을 위한 제언  \n   C. 독자에게의 메시지  \n\n이 아웃라인은 AI가 고용 시장에 미치는 다양한 영향을 포괄적으로 다루며, 긍정적인 측면과 부정적인 측면을 균형 있게 제시합니다. 또한, 미래의 고용 시장에 대한 전망과 정책적 대응 방안도 포함하여 독자에게 유익한 정보를 제공합니다.', pydantic=None, json_dict=None, agent='outline_generator', output_format=<OutputFormat.RAW: 'raw'>, messages=[{'role': 'system', 'content': 'You are outline_generator. \n        You are an expert at organizing information and creating comprehensive outlines for various subjects.\n        \nYour personal goal is: Create structured outlines for articles on given topics. answer in Korean.\nTo give my best complete final answer to the task respond using the exact following format:\n\nThought: I now can give a great answer\nFinal Answer: Your final answer must be the great and the most complete as possible, it must be outcome described.\n\nI MUST use these formats, my job depends on it!'} ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
print(result)
# Out:
# # AI가 고용 시장에 미치는 영향: 긍정적 측면과 부정적 측면
#
# ## I. 서론
# AI(인공지능)는 기계가 인간의 지능을 모방하여 문제를 해결하고 학습할 수 있는 능력을 부여하는 기술입니다. 지난 몇십 년 간의 급속한 발전은 다양한 분야에서 AI의 영향을 확산시키고 있으며, 이로 인해 고용 시장 또한 큰 변화를 겪고 있습니다. 본 기사는 AI의 발전이 고용 시장에 미치는 영향을 심층적으로 분석하며, 긍정적인 영향과 부정적인 영향을 균형 있게 조명하려고 합니다.
#
# ## II. AI의 발전과 고용 시장의 변화
# 현재 AI 기술의 발전은 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 분야에서 진행되고 있습니다. 이러한 기술들은 업무 효율성을 높이고 새로운 비즈니스 모델을 창출하는 데 기여하고 있습니다. 결과적으로 전통적인 직업에 대한 수요는 감소하는 반면, AI와 관련된 새로운 직업이 등장하고 있습니다.
#
# ## III. AI의 긍정적인 영향
# ### A. 생산성 향상
# AI는 업무 효율성을 크게 향상시킵니다. 반복적인 업무가 자동화됨으로써 직원들은 더 창의적이고 전략적인 업무에 집중할 수 있습니다. 이는 비용 절감과 더불어 기업의 전반적인 생산성을 높이는 데 기여합니다.
#
# ### B. 새로운 직업 창출
# AI의 출현은 많은 새로운 직업을 만들어냈습니다. AI 기술을 개발하고 관리하는 직무는 물론, 기술 지원 능능력이 중요한 역할을 하게 되었습니다.
#
# ### C. 직무의 질 향상
# AI 덕분에 반복적인 업무가 줄어들고, 이로 인해 직원들이 보다 전문 분야에서 발전할 수 있는 기회를 얻게 됩니다. 창의성과 전략 수립에 더 많은 시간과 자원을 투자할 수 있는 환경이 조성되고 있습니다.
#
# ## IV. AI의 부정적인 영향
# ### A. 일자리 감소
# 동시에 AI는 일부 일자리를 대체하고 있습니다. 특히, 자동화에 의해 특정 산업의 전통적인 작업이 사라지면서 일자리 감소가 발생하고 있습니다.
#
# ### B. 기술 격차 확대
# AI 기술은 고급 기술을 요구하는 직업의 수를 증가시키고, 특히 저숙련 노동자는 직업을 잃거나 대체될 위험에 처하게 됩니다. 이로 인해 기술 격차가 더욱 심화되고 있습니다.
#
# ### C. 사회적 불평등 심화
# 고소득 직업과 저소득 직업 간의 격차가扩大되고 있으며, 이는 지역 간 고용 불균형으로 이어지고 있습니다. 일부 지역은 AI 기술의 혜택을 누리는 반면, 다른 지역은 고용 기회가 줄어드는 상황이 발생하고 있습니다.
#
# ## V. AI와 고용 시장의 미래
# 앞으로는 AI와 인간의 협업 가능성이 제기되고 있습니다. 인간과 AI의 역할 분담을 통해 인류의 다양한 업무를 더욱 효과적으로 수행할 수 있는 방법이 모색되고 있습니다. 또한, 기술 변화에 적응하기 위한 교육과 재훈련의 중요성이 강조되고 있으며, 평생 학습의 필요성이 대두되고 있습니다. 정부와 기업은 이러한 변화에 대응하기 위해 정책적 접근 방식과 책임을 가져야 합니다.
#
# ## VI. 결론
# AI는 고용 시장에 긍정적이고 부정적인 영향을 모두 미치고 있습니다. 미래의 고용 시장은 빠르게 변화하고 있으며, 이에 대한 대응책을 마련하는 것이 중요합니다. 따라서 독자 여러분께서는 이러한 변화에 발맞추어 기회를 잡고, 기술 변화에 대해 열린 마음으로 학습하는 것이 필요합니다. AI 시대에 적응하기 위해서는 계속해서 학습하고 성장하는 태도가 중요합니다.

# %% [markdown]
# # Process 정의

# %% [markdown]
# - 주어진 작업 흐름에 맞게 작업이 수행되도록 함

# %%
from crewai.process import Process
# 프로세스 생성
ai_impact_crew = Crew(
    agents=[outline_generator, writer],
    tasks=[outline_task, writing_task], 
    # verbose=True,
    Process=Process.sequential
)

# %%
# Crew 실행
result2 = ai_impact_crew.kickoff()
result2
# Out:
# CrewOutput(raw='# AI가 고용 시장에 미치는 영향: 기회와 도전\n\n## I. 서론  \n인공지능(AI)은 기계가 인간의 지능을 모방하여 스스로 학습하고 문제를 해결할 수 있도록 하는 기술입니다. AI는 1950년대의 초기 연구부터 시작하여 최신 머신러닝 및 딥러닝 기술로 급속 발전하고 있습니다. 이러한 발전은 고용 시장에 큰 변화를 가져오고 있으며, 이는 단순히 직업의 종류를 바꾸는 것뿐만 아니라 전체 경제와 사회 구조에까지 영향을 미칩니다. 본 기사는 AI가 고용 시장에서 어떻게 작용하고 있는지를 살펴보며, 긍정적인 영향과 부정적인 영향을 균형 있게 검토하려고 합니다.\n\n## II. AI의 발전과 고용 시장의 변화  \n### A. AI 기술의 발전 현황  \nAI 기술은 머신러닝과 딥러닝의 도움으로 놀라운 속도로 발전하고 있습니다. 특히, 자연어 처리(NLP)와 이미지 인식 기술은 다양한 산업에서 사용되고 있으며, 이는 기업의 운영 방식을 변화시키고 있습니다.\n\n### B. 고용 시장의 변화 양상  \nAI의 발전은 전통적인 직업에 큰 영향을 미치고 있습니다.  \n1. **전통적인 직업의 변화**  \n   a. 많은 직업이 자동화되면서 일부 일자리는 대체되고 있습니다.  \n   b. 그 결과로, 직무의 재구성에 대한 필요성이 대두되고 있습니다.  \n2. **새로운 직업의 출현**  \n   a. AI 관련 직업이 증가하면서 데이터 분석가, AI 윤리 전문가 등 새로운 직업군이 생겨나고 있습니다.  \n   \n## III. AI의 긍정적인 영향  \n### A. 생산성 향상  \nAI는 업무 효율성을 크게 향상시킵니다. 반복적인 작업은 AI에 의해 자동화되므로 직원들은 더 창의적이고 전략적인 업무에 집중할 수 있게 됩니다. 이는 비용 절감과 수익성 향상으로 이어집니다.\n\n### B. 새로운 직업 창출  \nAI의 발전은 기술 개발과 유지보수 관련 직무를 증가시키고 있습니다. 여기에 더해, 창의적이고 전략적인 업무에 대한 수요도 증가하고 있습니다. 이는 결국 인력의 전문성을 높이는 기회가 됩니다.\n\n### C. 직무의 질 향상  \n반복적인 업무가 줄어들게 되면서 인간의 창의성과 문제 해결 능력을 더 잘 활용할 수 있는 환경이 조성됩니다. 결과적으로 직무의 질도 향상됩니다.\n\n## IV. AI의 부정적인 영향  \n### A. 일자리 감소  \nAI의 자동화로 인해 일부 일자리는 대체되고 있으며, 이는 특히 제조업이나 단순 반복 작업이 많은 직종에서 두드러집니다. 특정 산업의 고용 감소가 우려되는 상황입니다.\n\n### B. 기술 격차 확대  \nAI와 관련된 고급 기술을 요구하는 직업이 증가하면서 저숙련 노동자는 고용 시장에서 어려움을 겪고 있습니다. 이는 기술 격차를 더욱 심화시키고 있습니다.\n\n### C. 사회적 불평등 심화  \nAI의 발전은 고소득 직업과 저소득 직업 간의 격차를 더욱 확대합니다. 또한, 일부 지역에서는 고용 기회가 줄어들어 지역 간 고용 불균형이 발생하고 있습니다.\n\n## V. AI와 고용 시장의 미래  \n### A. AI와 인간의 협업 가능성  \n미래의 고용 시장은 AI와 인간의 협업이 필수적입니다. AI는 인간의 역할을 보완하며, 하이브리드 직무가 출현하게 됩니다.\n\n### B. 교육과 재훈련의 중요성  \n기술 변화에 적응하기 위해 교육과 재훈련은 반드시 필요합니다. 평생 학습의 중요성이 커지고 있습니다.\n\n### C. 정책적 대응 방안  \n정부는 AI 기술의 발전에 대한 정책과 규제를 마련해야 합니다. 사회 안전망 구축과 기업의 직원 재훈련 프로그램을 통해 기술 변화의 도전에 대처해야 합니다.\n\n## VI. 결론  \nAI는 고용 시장에 긍정적이고 부정적인 영향을 모두 미치고 있습니다. 따라서, 개인과 사회는 AI 시대의 기회와 도전을 인식하고 준비해야 합니다. 기술 변화에 능동적으로 대응하며 사회적 대화와 협력을 통해 함께 나아가는 것이 중요합니다. AI 시대에서 우리의 역할과 책임은 매우 커질 것입니다.', pydantic=None, json_dict=None, tasks_output=[TaskOutput(description="Create a detailed outline for the article about AI's impact on job markets.", name='outline_task', expected_output="\n    A comprehensive outline convering the main aspects of AI's influence on employment\n    ", summary="Create a detailed outline for the article about AI's impact...", raw='**AI의 고용 시장에 미치는 영향에 대한 기사 아웃라인**\n\nI. 서론  \n   A. AI의 정의 및 발전 배경  \n      1. 인공지능의 개념  \n      2. AI 기술의 역사적 발전  \n   B. AI가 고용 시장에 미치는 중요성  \n      1. 경제적 변화의 원동력  \n      2. 사회적 영향  \n\nII. AI의 발전과 고용 시장의 변화  \n   A. AI 기술의 발전 현황  \n      1. 머신러닝과 딥러닝의 발전  \n      2. 자연어 처리(NLP)와 이미지 인식 기술  \n   B. 고용 시장의 변화 양상  \n      1. 전통적인 직업의 변화  \n         a. 자동화로 인한 일자리 대체  \n         b. 직무의 재구성  \n      2. 새로운 직업의 출현  \n         a. AI 관련 직업의 증가  \n         b. 데이터 분석가, AI 윤리 전문가 등  \n\nIII. AI의 긍정적인 영향  \n   A. 생산성 향상  \n      1. 업무 효율성 증가  \n      2. 비용 절감 및 수익성 향상  \n   B. 새로운 직업 창출  \n      1. AI 기술 개발 및 유지보수 직무  \n      2. 창의적이고 전략적인 업무에 대한 수요 증가  \n   C. 직무의 질 향상  \n      1. 반복적인 업무의 자동화  \n      2. 인간의 창의성과 문제 해결 능력 활용  \n\nIV. AI의 부정적인 영향  \n   A. 일자리 감소  \n      1. 자동화로 인한 일자리 대체  \n      2. 특정 산업의 고용 감소  \n   B. 기술 격차 확대  \n      1. 고급 기술을 요구하는 직업의 증가  \n      2. 저숙련 노동자의 어려움  \n   C. 사회적 불평등 심화  \n      1. 고소득 직업과 저소득 직업 간의 격차  \n      2. 지역 간 고용 불균형  \n\nV. AI와 고용 시장의 미래  \n   A. AI와 인간의 협업 가능성  \n      1. 인간과 AI의 역할 분담  \n      2. 하이브리드 직무의 출현  \n   B. 교육과 재훈련의 중요성  \n      1. 기술 변화에 대한 적응 필요성  \n      2. 평생 학습의 필요성  \n   C. 정책적 대응 방안  \n      1. 정부의 역할  \n         a. 정책 및 규제 마련  \n         b. 사회 안전망 구축  \n      2. 기업의 책임  \n         a. 직원 재훈련 프로그램  \n         b. 윤리적 AI 개발  \n\nVI. 결론  \n   A. AI의 고용 시장에 대한 종합적 평가  \n   B. 미래의 고용 시장을 위한 제언  \n      1. 기술 변화에 대한 준비  \n      2. 사회적 대화와 협력의 필요성  \n   C. 독자에게의 메시지  \n      1. AI 시대의 기회와 도전  \n      2. 개인의 역할과 책임  \n\n이 아웃라인은 AI가 고용 시장에 미치는 다양한 영향을 포괄적으로 다루며, 긍정적인 측면과 부정적인 측면을 균형 있게 제시합니다. 또한, 미래의 고용 시장에 대한 전망과 정책적 대응 방안도 포함하여 독자에게 유익한 정보를 제공합니다.', pydantic=No ...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────────── Execution Traces ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  🔍 Detailed execution traces are available!                                                                    │
# │                                                                                                                 │
# │  View insights including:                                                                                       │
# │    • Agent decision-making process                                                                              │
# │    • Task execution flow and timing                                                                             │
# │    • Tool usage details                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):
# ┌───────────────────────── Tracing Preference Saved ──────────────────────────┐
# │                                                                             │
# │  Info: Tracing has been disabled.                                           │
# │                                                                             │
# │  Your preference has been saved. Future Crew/Flow executions will not       │
# │  collect traces.                                                            │
# │                                                                             │
# │  To enable tracing later, do any one of these:                              │
# │  • Set tracing=True in your Crew/Flow code                                  │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file              │
# │  • Run: crewai traces enable                                                │
# │                                                                             │
# └─────────────────────────────────────────────────────────────────────────────┘

# %%
print(result2.raw)
# Out:
# # AI가 고용 시장에 미치는 영향: 기회와 도전
#
# ## I. 서론
# 인공지능(AI)은 기계가 인간의 지능을 모방하여 스스로 학습하고 문제를 해결할 수 있도록 하는 기술입니다. AI는 1950년대의 초기 연구부터 시작하여 최신 머신러닝 및 딥러닝 기술로 급속 발전하고 있습니다. 이러한 발전은 고용 시장에 큰 변화를 가져오고 있으며, 이는 단순히 직업의 종류를 바꾸는 것뿐만 아니라 전체 경제와 사회 구조에까지 영향을 미칩니다. 본 기사는 AI가 고용 시장에서 어떻게 작용하고 있는지를 살펴보며, 긍정적인 영향과 부정적인 영향을 균형 있게 검토하려고 합니다.
#
# ## II. AI의 발전과 고용 시장의 변화
# ### A. AI 기술의 발전 현황
# AI 기술은 머신러닝과 딥러닝의 도움으로 놀라운 속도로 발전하고 있습니다. 특히, 자연어 처리(NLP)와 이미지 인식 기술은 다양한 산업에서 사용되고 있으며, 이는 기업의 운영 방식을 변화시키고 있습니다.
#
# ### B. 고용 시장의 변화 양상
# AI의 발전은 전통적인 직업에 큰 영향을 미치고 있습니다.
# 1. **전통적인 직업의 변화**
#    a. 많은 직업이 자동화되면서 일부 일자리는 대체되고 있습니다.
#    b. 그 결과로, 직무의 재구성에 대한 필요성이 대두되고 있습니다.
# 2. **새로운 직업의 출현**
#    a. AI 관련 직업이 증가하면서 데이터 분석가, AI 윤리 전문가 등 새로운 직업군이 생겨나고 있습니다.
#
# ## III. AI의 긍정적인 영향
# ### A. 생산성 향상
# AI는 업무 효율성을 크게 향상시킵니다. 반복적인 작업은 AI에 의해 자동화되므로 직원들은 더 창의적이고 전략적인 업무에 집중할 수 있게 됩니다. 이는 비용 절감과 수익성 향상으로 이어집니다.
#
# ### B. 새로운 직업 창출
# AI의 발전은 기술 개발과 유지보수 관련 직무를 증가시키고 있습니다. 여기에 더해, 창의적이고 전략적인 업무에 대한 수요도 증가하고 있습니다. 이는 결국 인력의 전문성을 높이는 기회가 됩니다.
#
# ### C. 직무의 질 향상
# 반복적인 업무가 줄어들게 되면서 인간의 창의성과 문제 해결 능력을 더 잘 활용할 수 있는 환경이 조성됩니다. 결과적으로 직무의 질도 향상됩니다.
#
# ## IV. AI의 부정적인 영향
# ### A. 일자리 감소
# AI의 자동화로 인해 일부 일자리는 대체되고 있으며, 이는 특히 제조업이나 단순 반복 작업이 많은 직종에서 두드러집니다. 특정 산업의 고용 감소가 우려되는 상황입니다.
#
# ### B. 기술 격차 확대
# AI와 관련된 고급 기술을 요구하는 직업이 증가하면서 저숙련 노동자는 고용 시장에서 어려움을 겪고 있습니다. 이는 기술 격차를 더욱 심화시키고 있습니다.
#
# ### C. 사회적 불평등 심화
# AI의 발전은 고소득 직업과 저소득 직업 간의 격차를 더욱 확대합니다. 또한, 일부 지역에서는 고용 기회가 줄어들어 지역 간 고용 불균형이 발생하고 있습니다.
#
# ## V. AI와 고용 시장의 미래
# ### A. AI와 인간의 협업 가능성
# 미래의 고용 시장은 AI와 인간의 협업이 필수적입니다. AI는 인간의 역할을 보완하며, 하이브리드 직무가 출현하게 됩니다.
#
# ### B. 교육과 재훈련의 중요성
# 기술 변화에 적응하기 위해 교육과 재훈련은 반드시 필요합니다. 평생 학습의 중요성이 커지고 있습니다.
#
# ### C. 정책적 대응 방안
# 정부는 AI 기술의 발전에 대한 정책과 규제를 마련해야 합니다. 사회 안전망 구축과 기업의 직원 재훈련 프로그램을 통해 기술 변화의 도전에 대처해야 합니다.
#
# ## VI. 결론
# AI는 고용 시장에 긍정적이고 부정적인 영향을 모두 미치고 있습니다. 따라서, 개인과 사회는 AI 시대의 기회와 도전을 인식하고 준비해야 합니다. 기술 변화에 능동적으로 대응하며 사회적 대화와 협력을 통해 함께 나아가는 것이 중요합니다. AI 시대에서 우리의 역할과 책임은 매우 커질 것입니다.

# %% [markdown]
# # 마크다운 형식으로 출력하기

# %%
from IPython.display import display, Markdown
display(Markdown(result.raw))
# Out:
# # AI가 고용 시장에 미치는 영향: 긍정적 측면과 부정적 측면
#
# ## I. 서론
# AI(인공지능)는 기계가 인간의 지능을 모방하여 문제를 해결하고 학습할 수 있는 능력을 부여하는 기술입니다. 지난 몇십 년 간의 급속한 발전은 다양한 분야에서 AI의 영향을 확산시키고 있으며, 이로 인해 고용 시장 또한 큰 변화를 겪고 있습니다. 본 기사는 AI의 발전이 고용 시장에 미치는 영향을 심층적으로 분석하며, 긍정적인 영향과 부정적인 영향을 균형 있게 조명하려고 합니다.
#
# ## II. AI의 발전과 고용 시장의 변화
# 현재 AI 기술의 발전은 머신러닝, 딥러닝, 자연어 처리(NLP), 로봇 공학 등 다양한 분야에서 진행되고 있습니다. 이러한 기술들은 업무 효율성을 높이고 새로운 비즈니스 모델을 창출하는 데 기여하고 있습니다. 결과적으로 전통적인 직업에 대한 수요는 감소하는 반면, AI와 관련된 새로운 직업이 등장하고 있습니다.
#
# ## III. AI의 긍정적인 영향
# ### A. 생산성 향상
# AI는 업무 효율성을 크게 향상시킵니다. 반복적인 업무가 자동화됨으로써 직원들은 더 창의적이고 전략적인 업무에 집중할 수 있습니다. 이는 비용 절감과 더불어 기업의 전반적인 생산성을 높이는 데 기여합니다.
#
# ### B. 새로운 직업 창출
# AI의 출현은 많은 새로운 직업을 만들어냈습니다. AI 기술을 개발하고 관리하는 직무는 물론, 기술 지원 능능력이 중요한 역할을 하게 되었습니다.
#
# ### C. 직무의 질 향상
# AI 덕분에 반복적인 업무가 줄어들고, 이로 인해 직원들이 보다 전문 분야에서 발전할 수 있는 기회를 얻게 됩니다. 창의성과 전략 수립에 더 많은 시간과 자원을 투자할 수 있는 환경이 조성되고 있습니다.
#
# ## IV. AI의 부정적인 영향
# ### A. 일자리 감소
# 동시에 AI는 일부 일자리를 대체하고 있습니다. 특히, 자동화에 의해 특정 산업의 전통적인 작업이 사라지면서 일자리 감소가 발생하고 있습니다.
#
# ### B. 기술 격차 확대
# AI 기술은 고급 기술을 요구하는 직업의 수를 증가시키고, 특히 저숙련 노동자는 직업을 잃거나 대체될 위험에 처하게 됩니다. 이로 인해 기술 격차가 더욱 심화되고 있습니다.
#
# ### C. 사회적 불평등 심화
# 고소득 직업과 저소득 직업 간의 격차가扩大되고 있으며, 이는 지역 간 고용 불균형으로 이어지고 있습니다. 일부 지역은 AI 기술의 혜택을 누리는 반면, 다른 지역은 고용 기회가 줄어드는 상황이 발생하고 있습니다.
#
# ## V. AI와 고용 시장의 미래
# 앞으로는 AI와 인간의 협업 가능성이 제기되고 있습니다. 인간과 AI의 역할 분담을 통해 인류의 다양한 업무를 더욱 효과적으로 수행할 수 있는 방법이 모색되고 있습니다. 또한, 기술 변화에 적응하기 위한 교육과 재훈련의 중요성이 강조되고 있으며, 평생 학습의 필요성이 대두되고 있습니다. 정부와 기업은 이러한 변화에 대응하기 위해 정책적 접근 방식과 책임을 가져야 합니다.
#
# ## VI. 결론
# AI는 고용 시장에 긍정적이고 부정적인 영향을 모두 미치고 있습니다. 미래의 고용 시장은 빠르게 변화하고 있으며, 이에 대한 대응책을 마련하는 것이 중요합니다. 따라서 독자 여러분께서는 이러한 변화에 발맞추어 기회를 잡고, 기술 변화에 대해 열린 마음으로 학습하는 것이 필요합니다. AI 시대에 적응하기 위해서는 계속해서 학습하고 성장하는 태도가 중요합니다.
